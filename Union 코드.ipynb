# %%
import pandas as pd
import geopandas as gpd
import fiona
from shapely.geometry import Point, Polygon, LineString
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.font_manager as fm

# %%
a = ['거주인구_200bf_dissolve','공공기관_dissolve','공원녹지_dissolve','상가_dissolve','호수_경기_통합']

# %%
GGD_Union = gpd.GeoDataFrame.from_file('D:/Analysis/BigData-PythonAnalysis-main/GGD/1. Union/거주인구_200bf_dissolve.shp',encoding = 'cp949')

for i in a:
    location = 'D:/Analysis/BigData-PythonAnalysis-main/GGD/1. Union/%s.shp'%i
    A = gpd.GeoDataFrame.from_file(location,encoding = 'cp949')
    GGD_Union = GGD_Union.union(A)
    print(i)
# Out:
# 거주인구_200bf_dissolve
# 공공기관_dissolve
# 공원녹지_dissolve
# 상가_dissolve
# 호수_경기_통합

# %%
GGD_Union = gpd.GeoDataFrame.from_file('D:/Analysis/BigData-PythonAnalysis-main/GGD/1. Union/1차결합_not하천.shp',encoding = 'cp949')
A = gpd.GeoDataFrame.from_file('D:/Analysis/BigData-PythonAnalysis-main/GGD/1. Union/경기도_하천_병합.shp',encoding = 'cp949')

# %%
A = A.set_crs('epsg:5181')

# %%
A.crs
# Out:
# <Projected CRS: EPSG:5181>
# Name: Korea 2000 / Central Belt
# Axis Info [cartesian]:
# - X[north]: Northing (metre)
# - Y[east]: Easting (metre)
# Area of Use:
# - name: Republic of Korea (South Korea) - between 126°E and 128°E - mainland and nearshore.
# - bounds: (126.0, 33.96, 128.0, 38.33)
# Coordinate Operation:
# - name: Korea Central Belt
# - method: Transverse Mercator
# Datum: Geocentric datum of Korea
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
GGD_Union = GGD_Union.union(A)
# Out:
# C:\Users\user\anaconda3\envs\geo_env\lib\site-packages\geopandas\base.py:31: UserWarning: The indices of the two GeoSeries are different.
#   warn("The indices of the two GeoSeries are different.")

# %%
GGD_Union.to_file('D:/Analysis/BigData-PythonAnalysis-main/GGD/1. Union/최종결합_경기.shp', driver='ESRI Shapefile')

# %%
Union.to_file('D:/Analysis/BigData-PythonAnalysis-main/GGD SHP/하천_diff.shp', driver='ESRI Shapefile')

# %%
a = (2,5,8)
type(a)
# Out:
# tuple

# %%
Union = gpd.GeoDataFrame.from_file('D:/Analysis/BigData-PythonAnalysis-main/KW/도로1_강원.shp',encoding = 'cp949')
Union = Union.dissolve(by = '1')
for i in a:
    location = 'D:/Analysis/BigData-PythonAnalysis-main/KW/도로%d_강원.shp'%i
    A = gpd.GeoDataFrame.from_file(location,encoding = 'cp949')
    A_dissolve = A.dissolve(by = '1')
    Union = Union.union(A_dissolve)
    print(i)
# Out:
# 2
# 5
# 8

# %%
Union.head()
# Out:
# 1
# 1    MULTILINESTRING ((364672.324 468665.873, 36467...
# dtype: geometry

# %%
Union.to_file('D:/Analysis/BigData-PythonAnalysis-main/KW/도로_강원_union_1.shp', driver='ESRI Shapefile')

# %%
Union = gpd.GeoDataFrame.from_file('D:/Analysis/BigData-PythonAnalysis-main/KW/도로1_강원.shp',encoding = 'cp949')
Union = Union.dissolve(by = '1')

# %%
River1 = gpd.GeoDataFrame.from_file('D:/Analysis/BigData-PythonAnalysis-main/GGD/7. 하천/소하천_50.shp',encoding = 'cp949')

# %%
River1['1'] = 1
River_disslove = River1.dissolve(by = '1')

# %%
River_disslove.to_file('D:/Analysis/BigData-PythonAnalysis-main/GGD/7. 하천/소하천_dissolve.shp', driver='ESRI Shapefile')

# %%
a = ('실폭하천_30','하천_용도구역_50','하천경계_50')

# %%
River1 = gpd.GeoDataFrame.from_file('D:/Analysis/BigData-PythonAnalysis-main/GGD/7. 하천/하천경계_50.shp',encoding = 'cp949')

# %%
River1.crs is None
# Out:
# True

# %%
Road1 = gpd.GeoDataFrame.from_file('D:/Analysis/BigData-PythonAnalysis-main/GGD/8. 호수 및 저수지/호수_경기_30.shp',encoding = 'cp949')
Road1['1'] = 1
Road1_Union = Road1.dissolve(by = '1')

# %%
Road1_Union.to_file('D:/Analysis/BigData-PythonAnalysis-main/GGD/8. 호수 및 저수지/호수_경기_통합.shp', driver='ESRI Shapefile')

# %%
for i in a:
    location = 'D:/Analysis/BigData-PythonAnalysis-main/GGD/7. 하천/%s.shp'%i
    A = gpd.GeoDataFrame.from_file(location,encoding = 'cp949')
    A['1'] = 1
    if A.crs is None:
        A = A.set_crs("EPSG:5181")        
    A_dissolve = A.dissolve(by = '1')
    River1_Union = River1_Union.union(A_dissolve)
    print(i)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_9924/4154408538.py:8: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:5174
# Right CRS: EPSG:5181
#
#   River1_Union = River1_Union.union(A_dissolve)
# 실폭하천_30
# 하천_용도구역_50
# C:\Users\user\AppData\Local\Temp/ipykernel_9924/4154408538.py:8: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:5174
# Right CRS: EPSG:5181
#
#   River1_Union = River1_Union.union(A_dissolve)
# 하천경계_50

# %%
River1_Union.to_file('D:/Analysis/BigData-PythonAnalysis-main/GGD/7. 하천/경기도하천_dissolve.shp', driver='ESRI Shapefile')

# %%
River1 = gpd.GeoDataFrame.from_file('D:/Analysis/BigData-PythonAnalysis-main/GGD/7. 하천/경기도_하천_병합.shp',encoding = 'cp949')

# %%
River_dissolve = River1.dissolve(by ='1')

# %%
River_dissolve.to_file('D:/Analysis/BigData-PythonAnalysis-main/GGD/7. 하천/경기도하천_dissolve.shp', driver='ESRI Shapefile')
